# %% [markdown]
# **Context**
# This data set contains monthly rainfall detail of 36 meteorological sub-divisions of India.
#
# **Content**
# Time Period: 1901 - 2015
#
# Granularity: Monthly
#
# Location: 36 meteorological sub-divisions in India
#
# Rainfall unit: mm
#
# **Acknowledgements**
# India Meteorological Department(IMD) Govt. of India has shared this dataset
# under Govt. Open Data License - India.

# %%
# !pip install kaggle

# %%
import matplotlib.pyplot as plt

# %%
# from google.colab import files

# uploaded = files.upload()

# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))
  
# # Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d rajanand/rainfall-in-india

# %%
# !unzip rainfall-in-india.zip

# %%
import pandas as pd

# %%
#Distric-wise rainfall normal
df1=pd.read_csv('dwrn.csv')
df1.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN  ...  Mar-May  Jun-Sep  Oct-Dec
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  ...    540.7   1207.2    892.1
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  ...    483.5   1757.2    705.3
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  ...    405.6   1884.4    574.7
# 3            ARUNACHAL PRADESH          LOHIT   42.2  ...    841.3   1848.5    231.0
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  ...    645.4   3008.4    268.1
#
# [5 rows x 19 columns]

# %%
df1.describe()
# Out:
#               JAN         FEB         MAR  ...      Mar-May     Jun-Sep      Oct-Dec
# count  641.000000  641.000000  641.000000  ...   641.000000   641.00000   641.000000
# mean    18.355070   20.984399   30.034789  ...   157.113105  1007.80234   142.714665
# std     21.082806   27.729596   45.451082  ...   213.445888   629.33261   148.951752
# min      0.000000    0.000000    0.000000  ...     1.500000    39.60000     5.600000
# 25%      6.900000    7.000000    7.000000  ...    27.800000   625.40000    51.600000
# 50%     13.300000   12.300000   12.700000  ...    67.200000   896.60000    86.700000
# 75%     19.200000   24.100000   33.200000  ...   172.400000  1193.80000   175.200000
# max    144.500000  229.600000  367.900000  ...  1256.500000  5228.00000  1048.500000
#
# [8 rows x 17 columns]

# %%
df1.isnull().sum()
# Out:
# STATE_UT_NAME    0
# DISTRICT         0
# JAN              0
# FEB              0
# MAR              0
# APR              0
# MAY              0
# JUN              0
# JUL              0
# AUG              0
# SEP              0
# OCT              0
# NOV              0
# DEC              0
# ANNUAL           0
# Jan-Feb          0
# Mar-May          0
# Jun-Sep          0
# Oct-Dec          0
# dtype: int64

# %%
df1.DISTRICT.value_counts()
#672 states
# Out:
# BIJAPUR        2
# BILASPUR       2
# AURANGABAD     2
# HAMIRPUR       2
# NICOBAR        1
#               ..
# GONDA          1
# GORAKHPUR      1
# HARDOI         1
# JAUNPUR        1
# LAKSHADWEEP    1
# Name: DISTRICT, Length: 637, dtype: int64

# %%
#rainfall in india 1901-2015 state-wise
df2=pd.read_csv('rin.csv')
df2.head()
# Out:
#                  SUBDIVISION  YEAR   JAN  ...  Mar-May  Jun-Sep  Oct-Dec
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2  ...    560.3   1696.3    980.3
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  ...    458.3   2185.9    716.7
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  ...    236.1   1874.0    690.6
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4  ...    506.9   1977.6    571.0
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3  ...    309.7   1624.9    630.8
#
# [5 rows x 19 columns]

# %%
df2.describe()
# Out:
#               YEAR          JAN  ...      Jun-Sep      Oct-Dec
# count  4116.000000  4112.000000  ...  4106.000000  4103.000000
# mean   1958.218659    18.957320  ...  1064.724769   154.100487
# std      33.140898    33.585371  ...   707.741531   166.942660
# min    1901.000000     0.000000  ...    57.400000     0.000000
# 25%    1930.000000     0.600000  ...   573.850000    34.200000
# 50%    1958.000000     6.000000  ...   881.100000    98.200000
# 75%    1987.000000    22.200000  ...  1288.175000   213.500000
# max    2015.000000   583.700000  ...  4536.900000  1252.500000
#
# [8 rows x 18 columns]

# %%
df2.isnull().sum()
#less number of null values hence can be removed
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
df2=df2.dropna()

# %%
df2.shape
# Out:
# (4090, 19)

# %%
df2['SUBDIVISION'].value_counts()
# Out:
# WEST RAJASTHAN                        115
# SOUTH INTERIOR KARNATAKA              115
# TAMIL NADU                            115
# RAYALSEEMA                            115
# TELANGANA                             115
# COASTAL ANDHRA PRADESH                115
# CHHATTISGARH                          115
# VIDARBHA                              115
# MATATHWADA                            115
# MADHYA MAHARASHTRA                    115
# KONKAN & GOA                          115
# SAURASHTRA & KUTCH                    115
# GUJARAT REGION                        115
# EAST MADHYA PRADESH                   115
# KERALA                                115
# EAST RAJASTHAN                        115
# NORTH INTERIOR KARNATAKA              115
# HIMACHAL PRADESH                      115
# PUNJAB                                115
# HARYANA DELHI & CHANDIGARH            115
# UTTARAKHAND                           115
# WEST UTTAR PRADESH                    115
# ...

# %%
df2[df2['SUBDIVISION']=='SUB HIMALAYAN WEST BENGAL & SIKKIM']
# Out:
#                             SUBDIVISION  YEAR   JAN  ...  Mar-May  Jun-Sep  Oct-Dec
# 437  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901  26.5  ...    238.9   1757.0     76.1
# 438  SUB HIMALAYAN WEST BENGAL & SIKKIM  1902   1.2  ...    484.6   2613.9     80.1
# 439  SUB HIMALAYAN WEST BENGAL & SIKKIM  1903   5.5  ...    201.9   2046.7    141.6
# 440  SUB HIMALAYAN WEST BENGAL & SIKKIM  1904   3.4  ...    458.8   1503.7    174.8
# 441  SUB HIMALAYAN WEST BENGAL & SIKKIM  1905  12.0  ...    447.0   2405.6    109.3
# ..                                  ...   ...   ...  ...      ...      ...      ...
# 547  SUB HIMALAYAN WEST BENGAL & SIKKIM  2011   8.5  ...    453.9   1858.6     77.7
# 548  SUB HIMALAYAN WEST BENGAL & SIKKIM  2012  15.3  ...    407.7   2056.0    139.3
# 549  SUB HIMALAYAN WEST BENGAL & SIKKIM  2013   3.0  ...    443.4   1717.6    218.5
# 550  SUB HIMALAYAN WEST BENGAL & SIKKIM  2014   0.2  ...    394.2   1862.6     38.9
# ...

# %%
df2.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May',
#        'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
df2=df2.melt(id_vars=["SUBDIVISION", "YEAR"], 
        var_name="MONTH", 
        value_name="VALUE")
df2.head()
# Out:
#                  SUBDIVISION  YEAR MONTH  VALUE
# 0  ANDAMAN & NICOBAR ISLANDS  1901   JAN   49.2
# 1  ANDAMAN & NICOBAR ISLANDS  1902   JAN    0.0
# 2  ANDAMAN & NICOBAR ISLANDS  1903   JAN   12.7
# 3  ANDAMAN & NICOBAR ISLANDS  1904   JAN    9.4
# 4  ANDAMAN & NICOBAR ISLANDS  1905   JAN    1.3

# %%
df2['MONTH'].value_counts()
# Out:
# JAN        4090
# OCT        4090
# Jun-Sep    4090
# Mar-May    4090
# Jan-Feb    4090
# ANNUAL     4090
# DEC        4090
# NOV        4090
# SEP        4090
# FEB        4090
# AUG        4090
# JUL        4090
# JUN        4090
# MAY        4090
# APR        4090
# MAR        4090
# Oct-Dec    4090
# Name: MONTH, dtype: int64

# %%
df2.drop(df2[ df2['MONTH']=='Oct-Dec'].index, inplace=True)
df2.drop(df2[ df2['MONTH']=='Mar-May'].index, inplace=True)
df2.drop(df2[ df2['MONTH']=='Jan-Feb'].index, inplace=True)
df2.drop(df2[ df2['MONTH']=='Jun-Sep'].index, inplace=True)

# %%
df3=df2[df2['SUBDIVISION']=='SUB HIMALAYAN WEST BENGAL & SIKKIM']

# %%
df3.head()
# Out:
#                             SUBDIVISION  YEAR MONTH  VALUE
# 425  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   JAN   26.5
# 426  SUB HIMALAYAN WEST BENGAL & SIKKIM  1902   JAN    1.2
# 427  SUB HIMALAYAN WEST BENGAL & SIKKIM  1903   JAN    5.5
# 428  SUB HIMALAYAN WEST BENGAL & SIKKIM  1904   JAN    3.4
# 429  SUB HIMALAYAN WEST BENGAL & SIKKIM  1905   JAN   12.0

# %%
df3=df3.sort_values(by=['YEAR'])

# %%
#sorting the dataset by time

months = ["JAN", "FEB", "MAR", "APR", "MAY", "JUN", 
          "JUL", "AUG", "SEP", "OCT", "NOV", "DEC"]
df3['MONTH'] = pd.Categorical(df3['MONTH'], categories=months, ordered=True)
df3.sort_values(by=['YEAR','MONTH'],inplace=True)  # same as you have now; can use inplace=True

# %%
df3.head(40)
# Out:
#                               SUBDIVISION  YEAR MONTH   VALUE
# 425    SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   JAN    26.5
# 4515   SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   FEB    14.8
# 8605   SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   MAR    14.1
# 12695  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   APR    29.2
# 16785  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   MAY   195.5
# 20875  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   JUN   488.4
# 24965  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   JUL   524.8
# 29055  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   AUG   501.1
# 33145  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   SEP   242.7
# 37235  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   OCT    55.5
# 41325  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   NOV    17.9
# 45415  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   DEC     2.6
# 49505  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901   NaN  2113.2
# 426    SUB HIMALAYAN WEST BENGAL & SIKKIM  1902   JAN     1.2
# ...

# %%
df3.dropna(inplace=True)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1380 entries, 425 to 45529
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  1380 non-null   object
#  1   YEAR         1380 non-null   int64
#  2   MONTH        1380 non-null   category
#  3   VALUE        1380 non-null   float64
# dtypes: category(1), float64(1), int64(1), object(1)
# memory usage: 44.9+ KB

# %%
df3[df3.MONTH.isnull()].count()
# Out:
# SUBDIVISION    0
# YEAR           0
# MONTH          0
# VALUE          0
# dtype: int64

# %%
from calendar import month_abbr

lower_ma = [m.lower() for m in month_abbr]
df3['MONTH'] = df3['MONTH'].str.lower().map(lambda m: lower_ma.index(m)).astype('Int8')

# %%
df3.head()
# Out:
#                               SUBDIVISION  YEAR  MONTH  VALUE
# 425    SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      1   26.5
# 4515   SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      2   14.8
# 8605   SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      3   14.1
# 12695  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      4   29.2
# 16785  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      5  195.5

# %%
df3['DATE']=1

# %%
df3.head()
# Out:
#                               SUBDIVISION  YEAR  MONTH  VALUE  DATE
# 425    SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      1   26.5     1
# 4515   SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      2   14.8     1
# 8605   SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      3   14.1     1
# 12695  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      4   29.2     1
# 16785  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      5  195.5     1

# %%
df3['YEAR'].value_counts()
# Out:
# 1901    12
# 1987    12
# 1985    12
# 1984    12
# 1983    12
#         ..
# 1935    12
# 1934    12
# 1933    12
# 1932    12
# 2015    12
# Name: YEAR, Length: 115, dtype: int64

# %%
df3['datetime']=[pd.to_datetime(str(a)+str(b)+str(c), format='%m%d%Y') for a,b,c in zip(df3.MONTH, df3.DATE, df3.YEAR)]

# %%
df3.head()
# Out:
#                               SUBDIVISION  YEAR  MONTH  VALUE  DATE   datetime
# 425    SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      1   26.5     1 1901-01-01
# 4515   SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      2   14.8     1 1901-02-01
# 8605   SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      3   14.1     1 1901-03-01
# 12695  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      4   29.2     1 1901-04-01
# 16785  SUB HIMALAYAN WEST BENGAL & SIKKIM  1901      5  195.5     1 1901-05-01

# %%
df3.drop(columns=['DATE', 'MONTH', 'YEAR'], inplace=True)

# %%
df3.head()
# Out:
#                               SUBDIVISION  VALUE   datetime
# 425    SUB HIMALAYAN WEST BENGAL & SIKKIM   26.5 1901-01-01
# 4515   SUB HIMALAYAN WEST BENGAL & SIKKIM   14.8 1901-02-01
# 8605   SUB HIMALAYAN WEST BENGAL & SIKKIM   14.1 1901-03-01
# 12695  SUB HIMALAYAN WEST BENGAL & SIKKIM   29.2 1901-04-01
# 16785  SUB HIMALAYAN WEST BENGAL & SIKKIM  195.5 1901-05-01

# %%
df3.drop(columns=['SUBDIVISION'], inplace=True)

# %%
df3.head()
# Out:
#        VALUE   datetime
# 425     26.5 1901-01-01
# 4515    14.8 1901-02-01
# 8605    14.1 1901-03-01
# 12695   29.2 1901-04-01
# 16785  195.5 1901-05-01

# %%
first_column = df3.pop('datetime')
df3.insert(0, 'datetime', first_column)
df3.head()
# Out:
#         datetime  VALUE
# 425   1901-01-01   26.5
# 4515  1901-02-01   14.8
# 8605  1901-03-01   14.1
# 12695 1901-04-01   29.2
# 16785 1901-05-01  195.5

# %%
df3=df3.set_index('datetime')
df3.tail()
# Out:
#             VALUE
# datetime
# 2015-08-01  626.6
# 2015-09-01  354.9
# 2015-10-01   53.6
# 2015-11-01   23.8
# 2015-12-01    9.0

# %%
df3.head()
# Out:
#             VALUE
# datetime
# 1901-01-01   26.5
# 1901-02-01   14.8
# 1901-03-01   14.1
# 1901-04-01   29.2
# 1901-05-01  195.5

# %%
df4=df3.resample('Y').mean().fillna(method='pad').plot(subplots=True, figsize=(15, 10))

# %%
df3
# Out:
#             VALUE
# datetime
# 1901-01-01   26.5
# 1901-02-01   14.8
# 1901-03-01   14.1
# 1901-04-01   29.2
# 1901-05-01  195.5
# ...           ...
# 2015-08-01  626.6
# 2015-09-01  354.9
# 2015-10-01   53.6
# 2015-11-01   23.8
# 2015-12-01    9.0
#
# [1380 rows x 1 columns]

# %%
df3.resample('Y').mean().fillna(method='pad').plot(subplots=True, figsize=(15, 10))
plt.plot()
plt.legend()
plt.grid(True)
plt.xlabel("Year",fontsize=15,fontweight="bold")
plt.ylabel("Mean Rainfall",fontsize=16,fontweight="bold")
plt.show()

# %%
#Considering only the last 30 years
df3 = df3['2000':'2015']

# %%
df3.head()
# Out:
#             VALUE
# datetime
# 2000-01-01   10.7
# 2000-02-01   36.2
# 2000-03-01   55.1
# 2000-04-01  185.1
# 2000-05-01  326.5

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result=seasonal_decompose(df3['VALUE'].dropna())
result.plot()
plt.show()

# %% [markdown]
# Seasonality is observed but no specific trend

# %%
df3['VALUE'].plot()

# %%
# Augmented Dickey–Fuller test
from statsmodels.tsa.stattools import adfuller

def perform_dickey_fuller_test(ts):
    result = adfuller(ts, autolag='AIC')
    print('ADF statistic: {}'.format(result[0]))
    print('p-value: {}'.format(result[1]))
    print('lags used: {}'.format(result[2]))
    print("Num Of Observations Used For ADF Regression and Critical Values Calculation :", result[3])
    print('Critical Values:' ,result[4])

perform_dickey_fuller_test(df3.VALUE)
# Out:
# ADF statistic: -3.603224296130486
# p-value: 0.005699684473284903
# lags used: 12
# Num Of Observations Used For ADF Regression and Critical Values Calculation : 179
# Critical Values: {'1%': -3.4674201432469816, '5%': -2.877826051844538, '10%': -2.575452082332012}

# %% [markdown]
# For building a time-series model, data needs to be stationary.
#
# The data is stationary if:
#
# 1) p-value < 0.05
#
# 2) ADF-statistic < critical values
#
# Here, condition (1) and (2) are satisfied, hence **data is stationary**.

# %% [markdown]
# Lets plot auto-correlation and partial auto-correlation for the differenced series
#
# **Auto-Correlation plot will help find MA order** and **partial-autocorrelation for AR order** i.e the order of p,q for time series model

# %%
#We use differencing to remove seasonality
df4=df3.diff(periods=12)
df4.dropna(inplace=True)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig=plt.figure(figsize=(15, 10))
ax1=fig.add_subplot(211)
fig=plot_acf(df3['VALUE'].dropna(), lags=30, ax=ax1)
ax2=fig.add_subplot(212)
fig=plot_pacf(df3['VALUE'].dropna(), lags=30, ax=ax2)

# %%
fig=plt.figure(figsize=(15, 10))
ax1=fig.add_subplot(211)
fig=plot_acf(df4['VALUE'].dropna(), lags=30, ax=ax1)
ax2=fig.add_subplot(212)
fig=plot_pacf(df4['VALUE'].dropna(), lags=30, ax=ax2)

# %% [markdown]
# #We're getting a decaying pattern over time on ACF, hence we're likely dealing with an Autoregressive process.

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
df3["2000-01-01":"2015-01-01"]
# Out:
#             VALUE
# datetime
# 2000-01-01   10.7
# 2000-02-01   36.2
# 2000-03-01   55.1
# 2000-04-01  185.1
# 2000-05-01  326.5
# ...           ...
# 2014-09-01  371.5
# 2014-10-01   31.2
# 2014-11-01    5.3
# 2014-12-01    2.4
# 2015-01-01   15.7
#
# [181 rows x 1 columns]

# %%
train=df3["VALUE"]["2000-01-01":"2013-01-01"].to_frame() #to convert series object to dataframe
test=df3["VALUE"]["2013-01-01":"2015-01-01"].to_frame()

train.shape,test.shape
# Out:
# ((157, 1), (25, 1))

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
train
# Out:
#             VALUE
# datetime
# 2000-01-01   10.7
# 2000-02-01   36.2
# 2000-03-01   55.1
# 2000-04-01  185.1
# 2000-05-01  326.5
# ...           ...
# 2012-09-01  434.7
# 2012-10-01  119.4
# 2012-11-01   12.5
# 2012-12-01    7.4
# 2013-01-01    3.0
#
# [157 rows x 1 columns]

# %%
#Creating ARMA
model=ARMA(train, order=(8,0)) #AR order = 2 as it's significant in PACF, and MA order = 0 as we're plotting an AR model
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
#Fitting the data
model_fit=model.fit()

# %%
#Print summary
print(model_fit.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                  VALUE   No. Observations:                  157
# Model:                     ARMA(8, 0)   Log Likelihood                -924.020
# Method:                       css-mle   S.D. of innovations             85.162
# Date:                Sat, 05 Feb 2022   AIC                           1868.041
# Time:                        11:34:05   BIC                           1898.603
# Sample:                    01-01-2000   HQIC                          1880.453
#                          - 01-01-2013
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         216.5194      2.974     72.810      0.000     210.691     222.348
# ar.L1.VALUE     0.2318      0.068      3.386      0.001       0.098       0.366
# ar.L2.VALUE    -0.0940      0.070     -1.352      0.178      -0.230       0.042
# ...

# %%
#Getting prediction start and end dates
pred_start_date=test.index[0]
pred_end_date=test.index[-1]

# %%
pred_start_date
# Out:
# Timestamp('2013-01-01 00:00:00')

# %%
#get predictions and residuals
predictions=model_fit.predict(start=test.index[0], end=test.index[-1])
residuals=test-predictions

# %%
#RMSE
from sklearn.metrics import mean_squared_error

rmse=mean_squared_error(test["VALUE"].values,predictions,squared=False)
rmse
# Out:
# 81.94359672122387

# %% [markdown]
# ARMA(8,0) gives RMSE=81.94

# %%
from datetime import timedelta
from datetime import date

# %%
timedelta(days=2)
# Out:
# datetime.timedelta(days=2)

# %%
for ed in test.index:
  ld=ed.replace(day=1)-timedelta(days=1) #last day of prev month
  print(ed, ed.replace(day=1)-timedelta(days=ld.day))
# Out:
# 2013-01-01 00:00:00 2012-12-01 00:00:00
# 2013-02-01 00:00:00 2013-01-01 00:00:00
# 2013-03-01 00:00:00 2013-02-01 00:00:00
# 2013-04-01 00:00:00 2013-03-01 00:00:00
# 2013-05-01 00:00:00 2013-04-01 00:00:00
# 2013-06-01 00:00:00 2013-05-01 00:00:00
# 2013-07-01 00:00:00 2013-06-01 00:00:00
# 2013-08-01 00:00:00 2013-07-01 00:00:00
# 2013-09-01 00:00:00 2013-08-01 00:00:00
# 2013-10-01 00:00:00 2013-09-01 00:00:00
# 2013-11-01 00:00:00 2013-10-01 00:00:00
# 2013-12-01 00:00:00 2013-11-01 00:00:00
# 2014-01-01 00:00:00 2013-12-01 00:00:00
# 2014-02-01 00:00:00 2014-01-01 00:00:00
# 2014-03-01 00:00:00 2014-02-01 00:00:00
# 2014-04-01 00:00:00 2014-03-01 00:00:00
# 2014-05-01 00:00:00 2014-04-01 00:00:00
# 2014-06-01 00:00:00 2014-05-01 00:00:00
# 2014-07-01 00:00:00 2014-06-01 00:00:00
# 2014-08-01 00:00:00 2014-07-01 00:00:00
# 2014-09-01 00:00:00 2014-08-01 00:00:00
# 2014-10-01 00:00:00 2014-09-01 00:00:00
# 2014-11-01 00:00:00 2014-10-01 00:00:00
# ...

# %%
for ed in test.index:
  print(ed-timedelta(days=1))
# Out:
# 2012-12-31 00:00:00
# 2013-01-31 00:00:00
# 2013-02-28 00:00:00
# 2013-03-31 00:00:00
# 2013-04-30 00:00:00
# 2013-05-31 00:00:00
# 2013-06-30 00:00:00
# 2013-07-31 00:00:00
# 2013-08-31 00:00:00
# 2013-09-30 00:00:00
# 2013-10-31 00:00:00
# 2013-11-30 00:00:00
# 2013-12-31 00:00:00
# 2014-01-31 00:00:00
# 2014-02-28 00:00:00
# 2014-03-31 00:00:00
# 2014-04-30 00:00:00
# 2014-05-31 00:00:00
# 2014-06-30 00:00:00
# 2014-07-31 00:00:00
# 2014-08-31 00:00:00
# 2014-09-30 00:00:00
# 2014-10-31 00:00:00
# 2014-11-30 00:00:00
# 2014-12-31 00:00:00

# %%
last_day_of_prev_month = date.today().replace(day=1) - timedelta(days=1)
start_day_of_prev_month = date.today().replace(day=1) - timedelta(days=last_day_of_prev_month.day)
print(last_day_of_prev_month,start_day_of_prev_month )
# Out:
# 2022-01-31 2022-01-01

# %%
#Rolling Forecast Origins
predictions_rolling=pd.Series()
for end_date in test.index:
  ld=end_date.replace(day=1)-timedelta(days=1) #last day of prev month)
  train=df3[:end_date.replace(day=1)-timedelta(days=ld.day)]
  model=ARMA(train, order=(8,0))
  model_fit=model.fit()
  pred=model_fit.predict(end_date)
  predictions_rolling.loc[end_date]=pred.loc[end_date]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
# ...

# %%
predictions_rolling

# %%
residuals_rolling=test-predictions_rolling

# %%
from sklearn.metrics import mean_squared_error

rmse=mean_squared_error(test["VALUE"].values,predictions_rolling,squared=False)
rmse

# %% [markdown]
# #ROLLING F0RECAST ORIGIN with an AR(8) leading to an RMSE of 80.5

# %% [markdown]
# #Fitting SARIMA MODEL

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
my_order=(0, 1, 0)
my_seasonal_order=(1, 0, 1, 12)
model=SARIMAX(train, order=my_order, seasonal_order=my_seasonal_order)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
#fit the model
model_fit = model.fit()

# %%
print(len(test))
# Out:
# 25

# %%
#get the predictions and residuals
predictions = model_fit.forecast(len(test))
predictions = pd.Series(predictions, index=test.index)
residuals = test - predictions

# %%
predictions[1:]
# Out:
# datetime
# 2013-02-01     18.882841
# 2013-03-01     54.364617
# 2013-04-01    139.936707
# 2013-05-01    235.108967
# 2013-06-01    454.942981
# 2013-07-01    575.261001
# 2013-08-01    411.933113
# 2013-09-01    330.612751
# 2013-10-01    127.878845
# 2013-11-01      5.241782
# 2013-12-01     -3.735594
# 2014-01-01      2.401743
# 2014-02-01     18.278881
# 2014-03-01     53.747917
# 2014-04-01    139.289281
# 2014-05-01    234.427369
# 2014-06-01    454.182448
# 2014-07-01    574.457266
# 2014-08-01    411.188024
# 2014-09-01    329.896860
# 2014-10-01    127.235749
# 2014-11-01      4.642720
# 2014-12-01     -4.331432
# 2015-01-01      1.803701
# dtype: float64

# %% [markdown]
# RESIDUALS from SARIMA

# %%
def evaluate_models(dataset, p_values, d_values, q_values):
  dataset = dataset.astype('float32')
  best_score, best_cfg = float("inf"), None
  for p in p_values:
    for d in d_values:
      for q in q_values:
        order = (p,d,q)
        try:
          rmse = evaluate_arima_model(dataset, order)
          if rmse < best_score:
            best_score, best_param = rmse, order
          print('ARIMA%s RMSE=%.3f' % (order,rmse))
        except:
          continue
print('Best ARIMA%s RMSE=%.3f' % (best_param, best_score))
# load dataset
series = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)
# evaluate parameters
p_values = range(0, 5)
d_values = range(0, 2)
q_values = range(0, 2)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)

# %%
#start_date=["2000-01-01":"2013-01-01"].to_frame() #to convert series object to dataframe
test=df3["VALUE"]["2013-01-01":"2015-01-01"].to_frame()

# %%
plt.figure(figsize=(20, 4))

plt.plot(df3)
plt.plot(predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Rainfall', fontsize=20)
#plt.ylabel('', fontsize=16)
for year in range(2000,2015):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
import numpy as np

# %%
test
# Out:
#             VALUE
# datetime
# 2013-01-01    3.0
# 2013-02-01   23.6
# 2013-03-01   32.1
# 2013-04-01  114.7
# 2013-05-01  296.5
# 2013-06-01  404.9
# 2013-07-01  588.4
# 2013-08-01  416.3
# 2013-09-01  308.0
# 2013-10-01  199.8
# 2013-11-01   16.1
# 2013-12-01    2.7
# 2014-01-01    0.2
# 2014-02-01   26.6
# 2014-03-01   37.7
# 2014-04-01   47.9
# 2014-05-01  308.6
# 2014-06-01  543.2
# 2014-07-01  384.6
# 2014-08-01  563.3
# 2014-09-01  371.5
# 2014-10-01   31.2
# 2014-11-01    5.3
# 2014-12-01    2.4
# 2015-01-01   15.7

# %%
test
# Out:
#             VALUE
# datetime
# 2013-01-01    3.0
# 2013-02-01   23.6
# 2013-03-01   32.1
# 2013-04-01  114.7
# 2013-05-01  296.5
# 2013-06-01  404.9
# 2013-07-01  588.4
# 2013-08-01  416.3
# 2013-09-01  308.0
# 2013-10-01  199.8
# 2013-11-01   16.1
# 2013-12-01    2.7
# 2014-01-01    0.2
# 2014-02-01   26.6
# 2014-03-01   37.7
# 2014-04-01   47.9
# 2014-05-01  308.6
# 2014-06-01  543.2
# 2014-07-01  384.6
# 2014-08-01  563.3
# 2014-09-01  371.5
# 2014-10-01   31.2
# 2014-11-01    5.3
# 2014-12-01    2.4
# 2015-01-01   15.7

# %%
predictions.dropna()
# Out:
# datetime
# 2013-02-01     18.882841
# 2013-03-01     54.364617
# 2013-04-01    139.936707
# 2013-05-01    235.108967
# 2013-06-01    454.942981
# 2013-07-01    575.261001
# 2013-08-01    411.933113
# 2013-09-01    330.612751
# 2013-10-01    127.878845
# 2013-11-01      5.241782
# 2013-12-01     -3.735594
# 2014-01-01      2.401743
# 2014-02-01     18.278881
# 2014-03-01     53.747917
# 2014-04-01    139.289281
# 2014-05-01    234.427369
# 2014-06-01    454.182448
# 2014-07-01    574.457266
# 2014-08-01    411.188024
# 2014-09-01    329.896860
# 2014-10-01    127.235749
# 2014-11-01      4.642720
# 2014-12-01     -4.331432
# 2015-01-01      1.803701
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error

rmse=mean_squared_error(test["VALUE"][1:].values,predictions.dropna(),squared=False)
rmse
# Out:
# 66.44193149581847

# %%
rolling_predictions = test.copy()
for train_end in test.index:
    ld=train_end.replace(day=1)-timedelta(days=1) #last day of prev month)
    train_data=df3[:train_end.replace(day=1)-timedelta(days=ld.day)]
    model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
    model_fit = model.fit()

    pred = model_fit.forecast()
    rolling_predictions[train_end] = pred
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ...

# %%
test.head()

# %%
rolling_predictions

# %%
rolling_predictions.drop(columns=['VALUE'], inplace=True)

# %%
nrp=pd.Series(np.diag(rolling_predictions), index=[rolling_predictions.index, rolling_predictions.columns])

# %%
rolling_predictions

# %%
nrp.shape
# Out:
# (25,)

# %%
test["VALUE"].shape
# Out:
# (25,)

# %%
from sklearn.metrics import mean_squared_error

rmse=mean_squared_error(test["VALUE"].values,nrp,squared=False)
rmse
# Out:
# 111.68108059482721

# %% [markdown]
# **SARIMAX Model Building**
#
# SARIMAX takes arguments order=(p,d,q) & seasonal_order=(P,D,Q,s), so for this reason I have initialized parameters to grid search over the best parameters for SARIMAX.
#
# p -> AR model lags
#
# d -> differencing/intergration order
#
# q -> MA model lags

# %%
import itertools

p=d=q=range(0,2)

pdq=list(itertools.product(p,d,q)) #provides cartesian product of matrices
seasonal_pdq=[(x[0],x[1],x[2],12) for x in pdq]

# %% [markdown]
# This for loop will iterate over all combinations of initialized parameters, fit SARIMAX model with all combinations and parameters yeilding lowest AIC will be selected

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
l_rmse=10000
for pdq_params in pdq:
  for seasonal_pdq_params in seasonal_pdq:
    try:
      model= SARIMAX(train,
                    order=pdq_params,
                    seasonal_order=seasonal_pdq_params
                    )
      #result_aic= model.fit().aic
      predictions = model_fit.forecast(len(test))
      predictions = pd.Series(predictions, index=test.index)   

      rmse=mean_squared_error(test["VALUE"][1:].values,predictions.dropna(),squared=False)
      rmse
      if rmse<l_rmse: #To help find least rmse
        l_rmse=rmse
        order_opt=pdq_params
        seasonal_order_opt=seasonal_pdq_params

      print("SARIMAX({}x{}12)-AIC:{}".format(pdq_params, seasonal_pdq_params, rmse))
    except:
      continue
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ...

# %% [markdown]
# The following combinations will be used as our parameters for the SARIMAX model

# %%
print("Least rmse: {}\nSARIMAX Order: {}\nSARIMAX Seasonal Order: {}".format(l_rmse, order_opt, seasonal_order_opt))
# Out:
# Least rmse: 10000
# SARIMAX Order: (0, 0, 1)
# SARIMAX Seasonal Order: (1, 1, 1, 12)

# %%
model=SARIMAX(train,
             order=(0, 0, 1),
             seasonal_order=(1, 1, 1, 12)).fit()

model.summary()

# %%
model.plot_diagnostics(figsize=(20,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# Residual plot: There is no obvious patterns observed.
#
# Histogram + KDE plot: KDE curve is not similar to the normal distribution
#
# Normal Q-Q: Most of the data points lies around and on the red line
#
# Correlogram (ACF plot) :correlations for lag greater than one is not significant

# %% [markdown]
# **PREDICTING THE TEST DATA**

# %%
predict=model.get_prediction(start=len(train),
                             end=len(train)+len(test)-1)

# %% [markdown]
# Getting the upper and lower bounds of predicted values to help define confidence intervals

# %%
bounds=predict.conf_int() #returns confidence intervals (range of values likely to include a population value) with default significance level 95%
bounds.head()

# %%
lower_lim=bounds["lower VALUE"]
upper_lim=bounds["upper VALUE"]

# %%
predict_values=predict.predicted_mean
ax=train.plot(label="Training Data",figsize=(15, 10))
test.plot(label="Testing Data",ax=ax)
predict_values.plot(label="Predicted data",ax=ax)

ax.fill_between(bounds.index,lower_lim,upper_lim,color="magenta",alpha=0.2)
plt.xlabel("Months",fontsize=15,fontweight="bold")
plt.ylabel("Mean Rainfall",fontsize=15,fontweight="bold")
plt.grid(True)
plt.legend(loc="best")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

rmse=mean_squared_error(test["VALUE"].values,predict_values,squared=False)
rmse

# %%
test.tail()
